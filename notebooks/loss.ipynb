# %% [markdown]
# # Table of Contents
#  <p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib

matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
matplotlib.rc('font', size=14
             ) 
# %matplotlib inline

# %%
losses = [[4943.4276, 1562.0436],
[1193.7291, 681.7760],
[567.4516, 354.8290],
[317.6017, 202.6936],
[174.6864, 96.5619],
[71.9874, 36.5320],
[26.4420, 12.8508],
[9.1540, 4.2256],
[3.1064, 1.6667],
[1.4697, 1.0229],
[1.0633, 0.8690],
[0.9491, 0.8006],
[0.8849, 0.7500],
[0.8324, 0.7045],
[0.7818, 0.6599],
[0.7333, 0.6196],
[0.6903, 0.5841],
[0.6525, 0.5529],
[0.6191, 0.5258],
[0.5895, 0.5015],
[0.5632, 0.4797],
[0.5400, 0.4606],
[0.5188, 0.4433],
[0.4994, 0.4268],
[0.4811, 0.4115],
[0.4641, 0.3972],
[0.4481, 0.3839]]

loss_df = pd.DataFrame(data=losses, columns=['train', 'val'])

# %%
plt.plot(loss_df.train, label='train')
plt.plot(loss_df.val, label='val')

plt.ylabel('MSE loss')
plt.xlabel('Number of epochs')
# plt.ylim([0, 2000])
ax = plt.gca()
ax.set_yscale("log")
plt.legend()
plt.savefig('UNET_losses.pdf');
